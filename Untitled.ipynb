# %%
""" Christopher Adams
    4/18/17 
    Reading NetCdf Files 
"""
# Import NetCDF4 library and Dataset module:
import netCDF4
from netCDF4 import Dataset

# Store URL of remote data:
url = 'http://sos.maracoos.org/stable/dodsC/hrecos/stationHRALBP-agg.ncml'
#url = 'http://sos.maracoos.org/stable/dodsC/weatherflow/wflow700-agg.ncml'
#url = "http://sos.maracoos.org/stable/dodsC/hrecos/HRALBP/HRALBP_2017-04-18.nc"

# Get the dataset:
nc = netCDF4.Dataset(url)

# %%
# Output the whole dataset:
# print(nc)

# Output the info:
print("The id is: " + nc.id + "\n")
print("The license: " + nc.license + "\n")
print("The publisher email: " + nc.publisher_email + "\n")
print("publisher institution: " + nc.publisher_institution + "\n")
print("Data Model: " + nc.data_model + "\n")

# # Store the Dataset information:
# rootgrp = Dataset(url, "r", format="NETCDF4")

# # Output the Data model
# print ("The Data Model via Dataset is: " + rootgrp.data_model)

# forcastGroup = rootgrp.createGroup("forecasts")
# oceansGroup = rootgrp.createGroup("oceans")

# print("The groups setup: " + rootgrp.groups)
print nc.variables

# Close the root group:
nc.close()
# Out:
# The id is: HRALBP_2017-04-18
#
# The license: HRECOS requests that attribution be given whenever HRECOS material is reproduced and re- disseminated and the HRECOS Coordinator be notified prior to publications including any part of the data. Example citation: 'Hudson River Environmental Conditions Observing System. 2012. Albany Meteorological Station data. Accessed April 13th, 2036. http://www.hrecos.org/.'
#
# The publisher email: devops@asascience.com
#
# publisher institution: MARACOOS
#
# Data Model: NETCDF3_CLASSIC
#
# OrderedDict([(u'lat', <type 'netCDF4._netCDF4.Variable'>
# float32 lat()
#     units: degrees_north
#     standard_name: latitude
#     long_name: station latitude
#     axis: Y
#     valid_min: -90.0
#     valid_max: 90.0
#     comment: Station Latitude
#     _CoordinateAxisType: Lat
# unlimited dimensions:
# current shape = ()
# filling off
# ), (u'lon', <type 'netCDF4._netCDF4.Variable'>
# float32 lon()
#     units: degrees_east
#     standard_name: longitude
# ...
